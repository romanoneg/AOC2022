# %%
import numpy as np

# %%
data = np.array(open("day1.txt", "r").read().split('\n'))
data[data == ''] = 0
data = data.astype(int)
data = np.split(data, np.where(data == 0)[0])

# %%
print(data)
# Out:
# [array([], dtype=int32), array([], dtype=int32), array([], dtype=int32), array([], dtype=int32), array([], dtype=int32), array([], dtype=int32), array([], dtype=int32), array([7769]), array([], dtype=int32), array([7769]), array([], dtype=int32), array([], dtype=int32), array([], dtype=int32), array([], dtype=int32), array([], dtype=int32), array([], dtype=int32), array([], dtype=int32), array([], dtype=int32), array([], dtype=int32), array([], dtype=int32), array([], dtype=int32), array([], dtype=int32), array([7769]), array([], dtype=int32), array([], dtype=int32), array([], dtype=int32), array([], dtype=int32), array([], dtype=int32), array([], dtype=int32), array([], dtype=int32), array([], dtype=int32), array([], dtype=int32), array([7769]), array([], dtype=int32), array([], dtype=int32), array([], dtype=int32), array([], dtype=int32), array([], dtype=int32), array([], dtype=int32), array([7769]), array([], dtype=int32), array([], dtype=int32), array([], dtype=int32), array([], 
# ...
